# %% [markdown]
# #LIGHT CURVES FOR SEE-CHANGE

# %% [markdown]
# #SNe Type Ia

# %%
# %matplotlib inline
from notebookWidgets import createPlots

data_file = 'test.csv'
filters = ('f105w', 'f140w', 'f814w')

createPlots(*filters, type='Ia', filename=data_file)

# %% [markdown]
# #SNe Type Ib/c

# %%
createPlots(*filters, type='Ibc', filename=data_file)

# %% [markdown]
# # SNe Type II

# %%
createPlots(*filters, type='II', filename=data_file)

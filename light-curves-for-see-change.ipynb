# %% [markdown]
# #LIGHT CURVES FOR SEE-CHANGE

# %% [markdown]
# #SNe Type Ia

# %%
# %matplotlib inline
from updatedNotebook import parseFile

parseFile('/home/ubuntu/projects/classification/src/lightcurves/test.csv')

# %% [markdown]
# #SNe Type Ib/c

# %%
interact(lightcurves.plot_Ibc, z = FloatSliderWidget(min=0.15, max=2, step=0.05, value=1.60),
         phase = FloatSliderWidget(min=-50, max=100, step=10, value=0),
         hostebv_Ibc = FloatSliderWidget(min=-0.1, max=0.65, step=0.1, value=0),
         filters = fixed(filters),
         dates = fixed(my_dates),
         data_flux_filter1=fixed([1.2,1.96,1.02]), data_flux_filter1_err=fixed([0.26,0.23,0.23]),
         data_flux_filter2=fixed([1.15,1.89,1.75]), data_flux_filter2_err=fixed([0.2,0.19,0.21]),
         data_flux_filter3=fixed([0,0.6,0.41]), data_flux_filter3_err=fixed([0.3,0.18,0.22]));

# %% [markdown]
# # SNe Type II

# %%
interact(lightcurves.plot_II, z = FloatSliderWidget(min=0.15, max=2, step=0.05, value=1.60),
         phase = FloatSliderWidget(min=-50, max=100, step=10, value=0),
         hostebv_II = FloatSliderWidget(min=-0.1, max=0.65, step=0.1, value=0),
         filters = fixed(filters),
         dates = fixed(my_dates),
         data_flux_filter1=fixed([1.2,1.96,1.02]), data_flux_filter1_err=fixed([0.26,0.23,0.23]),
         data_flux_filter2=fixed([1.15,1.89,1.75]), data_flux_filter2_err=fixed([0.2,0.19,0.21]),
         data_flux_filter3=fixed([0,0.6,0.41]), data_flux_filter3_err=fixed([0.3,0.18,0.22]));
